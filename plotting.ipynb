# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

plt.rcParams['font.size'] = 18

# Importing
df = pd.read_csv('Generationlength.csv')

# Means
means = []
for i in df.columns[1:]:
    means.append(np.mean(df[i]))
# Plotting
fig, ax = plt.subplots(figsize = (18, 10))
ax.set_ylabel('Time')
sns.boxplot(data = df, color = 'cornflowerblue', ax = ax)
sns.swarmplot(data=df, palette='dark:k', size = 6, ax = ax)
ax.scatter(x = df.columns[1:], y = means, marker = 'X', s = 120)
plt.show()
print(f'Anzahl an Proben: {len(df)}')
# Out:
# Anzahl an Proben: 14
